# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Krishma-adhikari/flyrank-projects/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !pip -q install datasets huggingface_hub

# %%
import pandas as pd
from datasets import load_dataset
from google.colab import userdata
from huggingface_hub import login

# %%
HF_TOKEN = userdata.get("HF-TOKEN")
login(token=HF_TOKEN)

# %%
df = load_dataset("FlyRank/internship-warehouse",'fact_content_query_90d')

# %%
print(df)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['client_hash_id', 'content_hash_id', 'query_hash_id', 'query_char_count', 'query_token_count', 'window_start', 'window_end', 'impressions_90d', 'clicks_90d', 'impressions_last30', 'clicks_last30', 'impressions_prev30', 'clicks_prev30', 'avg_position_90d', 'avg_position_last30', 'avg_position_prev30', 'content_total_impressions_90d', 'content_visible_query_count', 'rare_query_count', 'rare_impressions_share', 'anonymized_impressions_share'],
#         num_rows: 2414248
#     })
# })

# %%
print(df.keys())
# Out:
# dict_keys(['train'])

# %%
df["train"].column_names
# Out:
# ['client_hash_id',
#  'content_hash_id',
#  'query_hash_id',
#  'query_char_count',
#  'query_token_count',
#  'window_start',
#  'window_end',
#  'impressions_90d',
#  'clicks_90d',
#  'impressions_last30',
#  'clicks_last30',
#  'impressions_prev30',
#  'clicks_prev30',
#  'avg_position_90d',
#  'avg_position_last30',
#  'avg_position_prev30',
#  'content_total_impressions_90d',
#  'content_visible_query_count',
#  'rare_query_count',
#  'rare_impressions_share',
#  'anonymized_impressions_share']

# %%
df["train"][:5]
# Out:
# {'client_hash_id': ['client_08a6a72ff48e62c0',
#   'client_08a6a72ff48e62c0',
#   'client_08a6a72ff48e62c0',
#   'client_08a6a72ff48e62c0',
#   'client_08a6a72ff48e62c0'],
#  'content_hash_id': ['content_447894f2faf0d2bc',
#   'content_447894f2faf0d2bc',
#   'content_447894f2faf0d2bc',
#   'content_447894f2faf0d2bc',
#   'content_447894f2faf0d2bc'],
#  'query_hash_id': ['query_58b1b001f839d699',
#   'query_922b8eca2a24cd34',
#   'query_9f0c36a6ae2a6a99',
#   'query_a032820b5467e996',
#   'query_ba1a2f131961c5da'],
#  'query_char_count': [17, 34, 16, 24, 18],
#  'query_token_count': [3, 7, 2, 4, 3],
#  'window_start': [datetime.date(2026, 4, 2),
#   datetime.date(2026, 4, 2),
#   datetime.date(2026, 4, 2),
#   datetime.date(2026, 4, 2),
#   datetime.date(2026, 4, 2)],
#  'window_end': [datetime.date(2026, 6, 30),
#   datetime.date(2026, 6, 30),
#   datetime.date(2026, 6, 30),
#   datetime.date(2026, 6, 30),
#   datetime.date(2026, 6, 30)],
#  'impressions_90d': [11, 13, 16, 55, 14],
#  'clicks_90d': [0, 0, 0, 0, 0],
#  'impressions_last30': [0, 0, 11, 1, 0],
#  'clicks_last30': [0, 0, 0, 0, 0],
#  'impressions_prev30': [11, 1, 5, 1, 0],
#  'clicks_prev30': [0, 0, 0, 0, 0],
#  'avg_position_90d': [10.818181818181818,
#   1.7692307692307692,
#   23.5625,
#   2.2,
#   3.4285714285714284],
#  'avg_position_last30': [None, None, 24.272727272727273, 13.0, None],
#  'avg_position_prev30': [10.818181818181818, 11.0, 22.0, 0.0, None],
#  'content_total_impressions_90d': [1466, 1466, 1466, 1466, 1466],
#  'content_visible_query_count': [14, 14, 14, 14, 14],
#  'rare_query_count': [32, 32, 32, 32, 32],
#  'rare_impressions_share': [0.04365620736698499,
#   0.04365620736698499,
#   0.04365620736698499,
#   0.04365620736698499,
#   0.04365620736698499],
#  'anonymized_impressions_share': [0.7251023192360164,
#   0.7251023192360164,
#   0.7251023192360164,
#   0.7251023192360164,
#   0.7251023192360164]}

# %%
df["train"].features
# Out:
# {'client_hash_id': Value('string'),
#  'content_hash_id': Value('string'),
#  'query_hash_id': Value('string'),
#  'query_char_count': Value('int64'),
#  'query_token_count': Value('int64'),
#  'window_start': Value('date32'),
#  'window_end': Value('date32'),
#  'impressions_90d': Value('int64'),
#  'clicks_90d': Value('int64'),
#  'impressions_last30': Value('int64'),
#  'clicks_last30': Value('int64'),
#  'impressions_prev30': Value('int64'),
#  'clicks_prev30': Value('int64'),
#  'avg_position_90d': Value('float64'),
#  'avg_position_last30': Value('float64'),
#  'avg_position_prev30': Value('float64'),
#  'content_total_impressions_90d': Value('int64'),
#  'content_visible_query_count': Value('int64'),
#  'rare_query_count': Value('int64'),
#  'rare_impressions_share': Value('float64'),
#  'anonymized_impressions_share': Value('float64')}

# %%
len(df["train"])
# Out:
# 2414248

# %%
dfn = pd.DataFrame(df)

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
# One row = One page for one month.
# I am using March 2026 because it is a mid panel month. I avoid June 2026 since it is the final month and should be treated as the outcome/test period.

# %%
march = dfn[dfn["window_start"] == "2026-03"]

print("Rows: ", len(march))
print("Unique Pages:", march["content_hash_id"].unique)

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
